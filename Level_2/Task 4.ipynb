# %%
import seaborn as sns  
import matplotlib.pyplot as plt  
import numpy as np  
np.random.seed(42)  
data = np.random.randn(50) * 10 + 50  
sns.boxplot(y=data, color="skyblue")
plt.title("Seaborn Boxplot of Random Data")
plt.show()
